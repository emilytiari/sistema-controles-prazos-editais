# %% [markdown]
# <a href="https://colab.research.google.com/github/emilytiari/sistema-controles-prazos-editais/blob/main/Aula_1_introdu%C3%A7%C3%A3o_ao_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("pronto para começar")
# Out:
# pronto para começar
